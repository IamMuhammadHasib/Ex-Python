# %%
from matplotlib import pyplot as plt
plt.plot([1, 6, 3], [9, 0, -1])
plt.show()

# %%
x = [3, 4, 2]
y = [9, 1, 6]
plt.plot(x, y)
plt.title("info")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
